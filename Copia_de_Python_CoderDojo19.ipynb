# %% [markdown]
# <a href="https://colab.research.google.com/github/seldoncode/Python_CoderDojo/blob/main/Copia_de_Python_CoderDojo19.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Juegos con Inteligencia artificial

# %% [markdown]
# ### Juego de los palillos
# * El [NIM](https://es.wikipedia.org/wiki/Nimrod_(videojuego)) es el precursor de los videojuegos, contruido en 1951.
# * El juego de los palillos similar al "juego de la última piedra"
# * Dados unos palillos iniciales, por ejemplo entre 16 y 23
# * Dos jugadores (persona y máquina) quitan por turnos 1 o 2 o 3 palillos
# * Comienza quitando el humano
# * El último en quitar gana
#
# Fases del juego:
#  1. Presentación del juego
#  2. Elección por el usuario de nivel (fácil / difícil)
#  3. Elección aleatoria de palillos iniciales (entre 16 y 23)
#  4. Elección aleatoria de palillos quitados:
#   - entre 1 y 3, o
#   - entre 1 y 4, o
#   - entre 1 y 5
#  5. El jugador humano comienza siempre el juego
#  6. Mostrar el área de juego con los palillos totales
#  7. Turno del jugador humano:
#   - Elige el número de palillos a quitar
#   - Se muestra el área de juego sin esos palillos
#   - Se cambia el turno
#  8. Turno de la máquina
#   - Si el nivel es fácil elige aleatoriamente
#   - Si el nivel es difícil llama a la IA
#   - Se muestra el área de juego sin los palillos retirados
#   - Se cambia el turno
#  9. Después de cada movimiento se comprueba si no hay más palillos:
#   - Si es así se comprueba quién cogió el último
#   - Se muestra el ganador de la partida
#  10. Si aún hay palillos, se sigue con el turno siguiente

# %%
'''Juego de los palillos o de Nim'''
import random
import time
import os

def presentacion_1():
    '''Mostramos una pantalla de inicio
    Se indica el nivel fácil o dificil que elige el usuario'''
    print()
    print("    *****************  JUEGO DE LOS PALILLOS   *****************")
    print()
    print()
    print("                 Gana quien coge el último palillo   ")
    print()
    print()
    print("                 1.   FÁCIL            2. DIFÍCIL")
    print()
    print()
    print("    ************************************************************")
    print()
    nivel = ""
    while nivel != "1" and nivel != "2":
        nivel = input("     Elige nivel(1/2): ")
    return nivel


def presentacion_2(palillos, quitas):
    '''Mostramos una segunda pantalla con los datos del juego,
    y pedimos al usuario que e enter para empezar.'''
    print()
    print("    *****************  JUEGO DE LOS PALILLOS   *****************")
    print()
    print()
    print(f"                 Habrá {palillos} palillos iniciales")
    print()
    print(f"                 Se pueden quitar entre 1 y {quitas}")
    print()
    print("                     Empiezas a mover tu")
    print()
    print("    ************************************************************")
    print()
    input("Pulsa Enter para empezar ...")

def sorteo_opciones():
    '''Devuelve dos valores aleatorios: Número de palillos iniciales (entre 16 y 23)
    y número máximo de palillos a quitar (entre 3 y 5)'''
    palillos = random.randint(16, 23)
    quitas = random.randint(3, 5)
    return palillos, quitas


def area_de_juego(palillos, quitas):
    '''Muestra los palillos que hay en cada jugada de la partida.'''
    print()
    print("    *****************  JUEGO DE LOS PALILLOS   *****************")
    print()
    print()
    for fila in range(4):
        print(end = "   ")
        for p in range(1, palillos+1):
            print("|", end = " ")
            if p % quitas == 0: # haciendo grupos de 4 palillos, o el nº de quitas que sea
                print(end = " ")  # un espacio más
        print()
    print()
    print()
    print()

def movimiento_jugador(palillos, quitas):
    '''Devuelve el número de palillos que el usuario quita en cada jugada'''
    if quitas == 3:
        quitas = ("1","2","3")
    elif quitas == 4:
        quitas = ("1","2","3","4")
    elif quitas == 5:
        quitas = ("1","2","3","4","5")

    q = input("     Palillos a quitar: ")
    while q not in quitas or int(q) > palillos:
        if q not in quitas:
            q = input(f"   Elige entre 1 y {len(quitas)}: ")
        elif int(q) > palillos:
            q = input("    Solo quedan {palillos} palillos: ")
        else:
            palillos_quitar = int(q)
    return palillos_quitar

'''
def movimiento_ordenador_ia_parcial(palillos, quitas):
    # Devuelve un número aleatorio de palillos a quitar como jugada del ordenador
    if palillos <= quitas:
        palillos_quitar = palillos
    else:
        palillos_quitar = random.randint(1, quitas)
        while palillos_quitar > palillos:
            palillos_quitar = random.randint(1, quitas)
    return palillos_quitar
'''

def movimiento_ordenador_aleatorio(palillos, quitas):
    '''Devuelve el número aleatorio de palillos a quitar como jugada del ordenador'''
    palillos_quitar = random.randint(1, quitas)
    while palillos_quitar > palillos:
        palillos_quitar = random.randint(1, quitas)
    return palillos_quitar 

def movimiento_ordenador_con_ia():
    '''Devuelve el número de palillos a quitar como jugada del ordenador
    calculados para que el ordenador gane siempre que pueda:
    se trata de dejar siempre un palillo más de los que se pueden quitar.
    Si quitas = 3, se han de dejar multiplos de 3+1= 4 palillos
    Si quitas = 4, se han de dejar múltiplos de 4+1 = 5 palillos'''
    pass

def mostrar_ganador(turno):
    '''Muestra pantalla final con el ganador de la partida: jugador u ordenador'''
    if turno == 2:
        mensaje1 = "               HAS TOMADO EL ÚLTIMO PALILLO"
        mensaje2 = "             * * *   HAS GANADO   * * * "
    elif turno == 1:
        mensaje1 = "               LA MÁQUINA TOMA EL ÚLTIMO PALILLO"
        mensaje2 = "             * * *   GANA LA MÁQUINA   * * * "
    print()
    print("    *****************  JUEGO DE LOS PALILLOS   *****************")
    print()
    print()
    print()
    print(mensaje1)
    print()
    print()
    print(mensaje2)
    print()
    print()


##########  Programa principal  #############

# Flujo del programa
turno = 1  # el jugador será turno 1, el ordenador turno 2
palillos, quitas = sorteo_opciones()

os.system("clear")   # si se ejecuta en Windows poner "cls"
nivel = presentacion_1() # la función retorna el nivel en el que quiere jugar el jugador

os.system("clear")   # si se ejecuta en Windows poner "cls"
presentacion_2(palillos, quitas)

jugando = True

while jugando:
    os.system("clear")   # si se ejecuta en Windows poner "cls"
    area_de_juego(palillos, quitas)
    if turno == 1:
        jugada = movimiento_jugador(palillos, quitas)
        turno = 2
    elif turno == 2:
        print("    El ordenador está pensando ...")
        time.sleep(2)
        if nivel == "1":
            jugada = movimiento_ordenador_aleatorio(palillos, quitas)
        elif nivel == "2":
            jugada = movimiento_ordenador_con_ia(palillos, quitas)
    
        turno = 1

    palillos -= jugada

    if palillos == 0:
        os.system("clear")   # si se ejecuta en Windows poner "cls"
        mostrar_ganador(turno)
        jugando = False
# Out:
#     *****************  JUEGO DE LOS PALILLOS   *****************
#
#
#                  Gana quien coge el último palillo
#
#
#                  1.   FÁCIL            2. DIFÍCIL
#
#
#     ************************************************************
#
#      Elige nivel(1/2): 1
#
#     *****************  JUEGO DE LOS PALILLOS   *****************
#
#
#                  Habrá 18 palillos iniciales
#
#                  Se pueden quitar entre 1 y 4
#
#                      Empiezas a mover tu
#
#     ************************************************************
#
# Pulsa Enter para empezar ...
#
#     *****************  JUEGO DE LOS PALILLOS   *****************
#
#
#    | | | |  | | | |  | | | |  | | | |  | |
#    | | | |  | | | |  | | | |  | | | |  | |
#    | | | |  | | | |  | | | |  | | | |  | |
#    | | | |  | | | |  | | | |  | | | |  | |
#
#
#
#      Palillos a quitar: 2
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-1-f6d8a117ac99> in <module>()
#     152     area_de_juego(palillos, quitas)
#     153     if turno == 1:
# --> 154         jugada = movimiento_jugador(palillos, quitas)
#     155         turno = 2
#     156     elif turno == 2:
#
# <ipython-input-1-f6d8a117ac99> in movimiento_jugador(palillos, quitas)
#      84         else:
#      85             palillos_quitar = int(q)
# ---> 86     return palillos_quitar
#      87
#      88 '''
#
# UnboundLocalError: local variable 'palillos_quitar' referenced before assignment
